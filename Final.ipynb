# %% [markdown]
# # EMPLOYEE COMPENSATION INTELLIGENCE
#
# # CHAPTER 1
#
# # PROJECT OVERVIEW
#
# **Domain:** Experience-Based Compensation Analytics
#
# **Objective:** To analyze employee experience, departmental distribution, and salary structure in order to understand how experience levels influence compensation patterns across the organization.
#
# **Business Problem:** The organization maintains employee records containing experience, department, and salary details, but lacks clear insight into whether compensation is consistently aligned with experience across different departments. The problem is to assess the relationship between employee experience and salary and identify departmental variations in pay structure.
#
# **Dataset:** An employee Dataset of a specific organization containing 5000 customer records with 19 features.

# %% [markdown]
# # CHAPTER 2
# # DATA LOADING AND INITIAL OVERVIEW
#
# Before performing any analysis, it is essential to load the dataset and understand its basic structure. This step helps in gaining familiarity with the dataset, identifying the number of records available, understanding the type of data present in each column, and spotting any immediate data quality issues such as missing values or incorrect data formats. A thorough initial overview ensures that appropriate data pre-processing steps can be planned effectively.
#
# # Step 1: Importing Required Library and Dataset
#
# We begin by importing the Pandas library, which provides efficient data structures and functions for data manipulation and analysis. The dataset is then loaded into a Pandas DataFrame.The alias 'pd' is a common convention.
#
#                     *Syntax:
#                     import pandas as pd
#
#                     file_name = "Uncleaned dataset (Dummy_5000_Employee_Details_Dataset).csv"
#
#                     df = pd.read_csv(file_name)*

# %%
import pandas as pd
file_name = "Uncleaned dataset (Dummy_5000_Employee_Details_Dataset).csv"
df = pd.read_csv(file_name)

# %% [markdown]
# # Step 2: Understanding Dataset Dimensions
#
# To understand the size of the dataset, we check the total number of rows and columns.
# Rows represent individual records or observations, while columns represent features or attributes.
# This gives an idea of how much data is available for analysis.
#
#                     *Syntax:
#                     df.shape*

# %%
print("Shape of dataset:", df.shape)
# Out:
# Shape of dataset: (5000, 19)

# %% [markdown]
# # Step 3: Checking Data Types of Columns
#
# To understand the columns better, we examine the data type of each column in the dataset.
# This step helps identify whether columns are stored as numeric, text, or date formats.
# It also helps detect columns that may require data type conversion before analysis.
#
#                         *Syntax:
#                         df.dtypes*

# %%
print("Data types:", df.dtypes)
# Out:
# Data types: Unnamed: 0              int64
# Name                   object
# Address                object
# Salary                float64
# DOJ                    object
# DOB                    object
# Age                     int64
# Sex                    object
# Dependents            float64
# HRA                   float64
# DA                    float64
# PF                    float64
# Gross Salary          float64
# Insurance              object
# Marital Status         object
# In Company Years        int64
# Year of Experience      int64
# Department             object
# Position               object
# dtype: object

# %% [markdown]
# # Step 4: Previewing the Dataset
#
# To get a quick visual understanding of how the data looks, we display the first few records.
# This helps verify whether the data has been loaded correctly and provides insight into column names, value ranges, and data patterns.
#
#                     *Syntax:
#                     df.head()
#                     df.tail()*

# %% [markdown]
# # Step 5: Dataset Information Summary
#
# We generate a concise summary of the dataset.
# This output provides details such as: Column names,Data types & Count of non-null values in each column.
# It is especially useful for identifying missing values and understanding memory usage.
#
#                     *Syntax:
#                     df.info()*

# %%
print("Head:", df.head())
# Out:
# Head:    Unnamed: 0      Name                              Address     Salary  \
# 0           0  VgwbPyBn  jyNxKZtk St, piZQhYcARo, PUN 172813  149289.04
# 1           1  pgdYaIWk  PypVsqug St, iHyelKZbFc, BLR 580530   69761.64
# 2           2  eWgVBGVv  pfQezTVa St, YfIaELfpUw, BLR 155186  107633.14
# 3           3  LYDofRRu  wcTsbmFr St, UdylzZFFCU, AMD 843852  147408.65
# 4           4  vhLFHcRg  DdxKVhli St, cYOjpbMztB, BLR 713383   53447.06
#
#           DOJ         DOB  Age     Sex  Dependents        HRA           DA  \
# 0  27-04-1998  27-03-1971   53   Other         2.0   8776.096  35233.66637
# 1  24-10-2020  12-12-1997   26    Male         0.0   9302.836  16464.42599
# 2  22-07-2020  20-08-1979   44  Female         2.0  13357.686  25402.46856
# 3  27-03-2007  07-06-1966   58    Male         1.0   6026.135  34789.87603
# 4  23-05-2017  19-11-1992   31    Male         2.0   7554.294  12614.02633
#
#              PF  Gross Salary Insurance Marital Status  In Company Years  \
# 0  22142.724760  171156.07760       NaN        Widowed                26
# 1  10347.127920   85181.77407      Both         Single                 3
# 2  15964.273030  130429.02150       NaN       Divorced                 3
# 3  21863.823120  166360.83790       NaN        Married                17
# 4   7927.330359   65688.04997      Life        Married                 7
#
#    Year of Experience       Department                    Position
# 0                  32            Sales              Sales Director
# 1                   5  Human Resources                HR Executive
# 2                  23        Marketing  Senior Marketing Executive
# 3                  37          Finance            Account Director
# 4                  10            Sales             Sales Executive

# %%
print("Tail:",df.tail())
# Out:
# Tail:       Unnamed: 0      Name                              Address     Salary  \
# 4995        4995  qWoLfJfL  ZySbqPyI St, ngMINtRCsM, MUB 927128  129159.11
# 4996        4996  bSgpJtiF  frtFLglE St, lTFYlKNUjF, HYD 805378  134664.03
# 4997        4997  gToCBVUH  EYXeRLkj St, VmMSAYuspF, HYD 735138   92852.65
# 4998        4998  dwTQETtZ  ivLjcIWM St, qWGPFaIuvI, KOL 978537   17412.05
# 4999        4999  EWrIRxIJ  vVrWcNkW St, NsOMLwTEmX, KOL 378650   91693.80
#
#              DOJ         DOB  Age     Sex  Dependents        HRA           DA  \
# 4995  27-01-2015  10-02-1975   49  Female         2.0   8769.089  30482.80698
# 4996  15-08-2010  18-12-1972   51  Female         3.0  10036.597  31782.02168
# 4997  18-09-2023  23-09-1985   38   Other         4.0   6651.735  21914.12908
# 4998  02-06-2023  20-07-2002   21   Other         0.0   6315.795   4109.41326
# 4999  09-06-2021  17-01-1988   36  Female         3.0   4421.620  21640.62920
#
#                 PF  Gross Salary Insurance Marital Status  In Company Years  \
# 4995  19157.030040  149253.97590   Medical       Divorced                 9
# 4996  19973.526200  156509.12250   Medical       Divorced                13
# 4997  13772.013490  107646.50060   Medical        Married                 0
# 4998   2582.575591   25254.68267      Both         Single                 1
# 4999  13600.131500  104155.91770       NaN        Married                 3
#
#       Year of Experience       Department                    Position
# 4995                  28               IT                  IT Manager
# 4996                  30            Sales      National Sales Manager
# 4997                  17               IT                     QA Lead
# 4998                   0  Human Resources           HR Representative
# 4999                  15        Marketing  Regional Marketing Manager

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
display(df)
# Out:
#       Unnamed: 0      Name                              Address     Salary  \
# 0              0  VgwbPyBn  jyNxKZtk St, piZQhYcARo, PUN 172813  149289.04
# 1              1  pgdYaIWk  PypVsqug St, iHyelKZbFc, BLR 580530   69761.64
# 2              2  eWgVBGVv  pfQezTVa St, YfIaELfpUw, BLR 155186  107633.14
# 3              3  LYDofRRu  wcTsbmFr St, UdylzZFFCU, AMD 843852  147408.65
# 4              4  vhLFHcRg  DdxKVhli St, cYOjpbMztB, BLR 713383   53447.06
# 5              5  mNWPWGPP  vuHIgjXl St, IodaWueNON, PUN 605979  106580.11
# 6              6  vjbszTQW  LLOOZxHr St, iiZXVGMuRa, DEL 672793  146007.75
# 7              7  zXUdTHaJ  XyBINigj St, BxfKiOEuiT, DEL 254142   76986.74
# 8              8  sIZQRTaq  ZrqSMeKj St, BSMxlzAcjl, BLR 743922  134973.46
# 9              9  DTjnhgxd  ZEeBgofu St, BGXeaFhWmT, CHN 978281  120881.83
# 10            10  eBRYbQan  wfXTduBi St, cVZIuyZwoH, PUN 942002  111585.44
# 11            11  eWLUSyxM  mXNzUhRW St, MNtLblAkxo, DEL 748567  110267.59
# 12            12  TNOqMntI  xPZmWZXy St, vbVuwQQynw, KOL 996770  137839.33
# 13            13  YEzLYCDP  dFNERDKi St, jWEHbKUscN, KOL 785625  112335.02
# 14            14  dTYeJIMp  uxCvqweZ St, cjbgwWkfII, MUB 484886   61292.38
# 15            15  WblJTjKQ  zXJyzhSA St, lwDImiwBuY, MUB 832618   54536.79
# 16            16  YoIurhqK  cwoNaCzs St, FahGyBPTBS, HYD 843200  125585.83
# 17            17  OYqIOSgW  ohQMGTOK St, teOUKLFQoc, HYD 193934  110283.78
# 18            18  rsCEIoFW  fEuEweIc St, tVHEqrUgRg, MUB 175099   87870.25
# 19            19  keBeAdyB  yShYbjuQ St, QineuRUlHw, AMD 905299  124569.61
# 20            20  wWrngMod  nqyFJlmb St, xIkJEmrTce, MUB 172623  144338.76
# 21            21  Donbudcg  GziMwnXj St, iKxDKBPWat, PUN 182853  126983.96
# 22            22  cBcpuWQy  rwecAngY St, bFZxVIqYMp, CHN 115558   85553.77
# 23            23  VrwdfHZs  TtquVXrb St, UlCtCDzYeN, KOL 674910   79408.29
# 24            24  DSBBGaaE  PCCoKGZj St, OkxtCRCEpG, PUN 748220   76946.32
# 25            25  dRECiNOs  SPnhEOug St, DwWEIdgGPa, HYD 778707   88732.50
# 26            26  wJmguwBV  llSHbDcL St, KEiTpwFNtA, KOL 530613  126765.30
# 27            27  kksePyxW  ausxCVIS St, SwGLigVXIQ, HYD 377530   87615.28
# 28            28  PpYXKeAt  oefEGXDy St, TLCLjzMlMc, BLR 908132  133741.54
# 29            29  nvPJxUPG  ByVLsdGA St, AFCxaNwORm, MUB 729149   48033.77
# 30            30  tdpUAGwI  aMUdzjpd St, GvozLitKxV, MUB 737307  138742.41
# 31            31  EpolrTHA  guYgwZPG St, MGWVFnbuif, DEL 639512   18488.03
# 32            32  siHwHrLM  VPtRPBhA St, JxRpbdxMNc, MUB 564520   86009.96
# 33            33  tAoxCwXO  UwyafFUm St, qubhZiWcOS, AMD 956551   87541.80
# 34            34  ndheFFHg  WobmQMjQ St, hkfEUGpRmp, MUB 377085  106180.52
# 35            35  VaIQIsuM  PCxQcPNK St, FUTYGoyhyM, MUB 454358   50564.32
# 68            68  OJFtcbPK  uVfrgcLS St, KvXtZUdgMW, HYD 120054  136795.50
# 69            69  rcPkexTB  tBNBEFRh St, QCjuarBiFW, AMD 703691  112095.02
# 70            70  bkdbauXE  EXvICXlY St, KPUWPPEQeT, HYD 115993   73884.08
# 71            71  kmSgplsr  irzbnBVy St, AThIatKKlp, MUB 779287   41792.31
# 72            72  SjGtIelJ  KCdSoQfV St, HusRZircZT, AMD 388510   89199.20
# 73            73  ZHaEUvZA  AUAGFgDk St, vWThnQRHIK, DEL 353492  135354.03
# 74            74  MCONOivL  DLovIsdg St, zzEHllVJWp, PUN 803821  142001.24
# 75            75  wlQOSwYN  CrMXScaK St, NwwqQcUmfE, BLR 710438  117850.87
# 76            76  IfXxhZyA  sQfnbchx St, IDtGgdyorE, CHN 416490  114637.84
# 77            77  hMCRQlQH  abDujkZO St, SBUsMWkMhR, AMD 981437  116021.64
# 78            78  WnKLmJPO  fqMtexys St, SBdzkspPxh, AMD 707369   57634.67
# 79            79  PdZJEXlp  osrDGpEH St, XxoKIktFha, HYD 370800   88424.55
# 80            80  SXRCZruV  fmxPHdHZ St, ZkBkvTMtjw, CHN 938584   60161.76
# 81            81  ZOSFDGQb  WsDIOrZU St, STcJLCxlHH, PUN 155839   40915.51
# 82            82  gICxDEyR  VdzvxmeN St, QhrKMycjsM, DEL 728306   52990.09
# 83            83  GNEvNSzV  mNeAckyH St, YlJRTZRFaW, PUN 838805   79927.21
# 84            84  duEqiDWJ  UCPUaDlg St, EnXIaOINAY, PUN 241355   87000.65
# 85            85  WByWjlRf  zPGRguoF St, VRPvnFVRyu, CHN 519224   75625.06
# 86            86  JaHwPArX  ZDtrWmVq St, GpkFDozAAs, KOL 493708  132686.43
# 87            87  pANfwnja  HHyXicPO St, hMuDXjHBXV, KOL 853204   52244.00
# 88            88  MFjducyw  BfHWvgen St, dunBPmGFyk, KOL 616248   78973.38
# 89            89  ogEMibGS  pDAIvJxY St, tjdWVgWUyz, MUB 170501   79355.82
# 90            90  zHDxHGFf  PuHfIFAq St, XYRwVavAom, BLR 497269  144551.30
# 91            91  OlowuOGX  mPkuTHjR St, fxwNmcbsDu, BLR 640647   30956.96
# 92            92  iHTBlAwJ  cCEkKZhR St, WmTZlPfbUG, BLR 262037  111079.70
# 93            93  dnAFNogc  xXhDiVqM St, iPePJSQyOD, CHN 944028  149265.40
# 94            94  OJKTOLwc  Twkpbrja St, wxoqWBVbPt, CHN 291463   79327.56
# 95            95  xyxvYQVW  xbzUIIdK St, hzJPEuCvCh, MUB 658433  113590.24
# 96            96  BFpuikPW  dQvqnLZH St, EjhMnaohie, AMD 738589   77792.89
# 97            97  LdnpmkTc  StScpkZE St, WJNXtWcfSC, BLR 915458  107838.16
# 98            98  eHoHmwyl  COQlXEzq St, WBCWJEwBLC, BLR 800185  110354.59
# 99            99  nKFdmLTF  OnMGFAQR St, lGvikyKHPY, BLR 575222  139274.80
# 100          100  IoCLcUhC  FISGJctP St, lFftAhjMaX, KOL 251312  146614.13
# 101          101  HsjVRxDF  bKclVqQn St, EzXuJAAdiF, BLR 366336  103784.41
# 102          102  YtQqWmQM  JVYiZQgW St, CrGQnIocgD, PUN 925197   37518.71
# 103          103  DblnKIdB  IhBuurpM St, TPUQtYbxVe, PUN 651697   83934.37
# 104          104  UAuUREok  cGwTYkJa St, pjCsIejiid, HYD 604650   46612.67
# 105          105  HWyHaYgE  exXFZKlE St, VpzYpaDvad, DEL 350379  120476.26
# 106          106  hSZQYOnk  UqgdFsNX St, KyYcGbpiaI, BLR 886508  138308.14
# 107          107  vzYPgXnQ  WadLQGKx St, HHrYNGRyfM, BLR 821572   33427.85
# 108          108  CzhymJvm  fztpAvTQ St, WWDGVTWfBZ, HYD 479259  131406.21
# 109          109  oqKYoVkX  SqBTWKVI St, yotOGMbmLd, AMD 976151   75701.80
# 110          110  AbdnQkmi  FNOOainS St, gYaNfsaSdu, CHN 180406   65118.58
# 111          111  dejNEqLA  EACCRyyv St, FFJlXmINCs, DEL 822500   76408.83
# 112          112  mxJctiOP  yLUDzewV St, zKlwAQJPlU, PUN 412675  115139.94
# 113          113  VthzMbvC  WtjooWWl St, MMdHoFmjON, AMD 431698   95873.63
# 114          114  hWAkAgUc  kPNiVRDt St, ZBPiPmmbOt, MUB 654230  109133.20
# 115          115  WkHDrHdz  PFTaFfIT St, gKxWAEtTxK, AMD 529062  116386.60
# 116          116  WJidoqZi  FzJleIss St, qUhoabayQK, MUB 259939   99010.26
# 117          117  JNzYsXrL  IMqpQrjB St, wwufFtFCtl, MUB 852477   93945.47
# 118          118  zOZigWEZ  nUHAjTfa St, yeGxMaxbfH, CHN 879611   99313.09
# 119          119  wnaiKGFz  WcpHDoHX St, FGnkAoDMzz, AMD 844168   98003.91
# 120          120  ktvzRsgU  zgHnFaeS St, dSikdJtRYM, CHN 675835   82255.04
# 121          121  lmdvLMbM  RuUdXiKE St, lmDXgMlTKR, KOL 853378   52589.75
# 122          122  QfUKjYBq  lJTEgIUM St, xGENuaGqae, KOL 527033   77317.24
# 123          123  MGVqUZbh  NQPwGGnA St, gUkimOltok, MUB 547658   76237.33
# 124          124  FNwuZByg  vQQaPjqq St, rSJtLxfgqg, CHN 549304   82205.58
# 125          125  KulcEVZE  eVxMwXRP St, sLWQzngKig, KOL 333049   49564.43
# 126          126  wQcjOciz  euEeCGrN St, CdGAggnZRr, MUB 227546  139492.82
# 127          127  mnOVFWYC  yDeUkYqk St, IEJQVykhmT, PUN 442511   85249.01
# 128          128  CLyiEjJJ  ulTYtlju St, FOPkdKSeSj, PUN 884998  140278.90
# 129          129  JkRfhrOH  RJtTeYvo St, eayQENbJGq, BLR 493487  103274.66
# 130          130  HLIVYqtW  EaDjiGvn St, DqRyDmBrdf, CHN 649106   45789.81
# 131          131  MOAynGWG  ZuRLPCsc St, YLmhIfHeTN, CHN 821560  124324.85
# 132          132  UerSZcwW  nacLmEfq St, gpvwtIRVun, DEL 294718   44395.07
# 133          133  QcEQLyys  OwywIUYD St, nNmcSpayOB, PUN 390910   91061.17
# 134          134  WfFjjloF  xYMAeOaA St, trIAxQYRqI, PUN 219105  107463.63
# 135          135  mbTqFxTE  JfDFhSEG St, TQmQvHGZqv, KOL 657514   84478.01
# 136          136  DxPLvFbh  tUKEMabx St, mFONpyDraH, HYD 665411   57412.22
# 137          137  JLodgfVl  DODTzcRk St, StJsZRaeRm, CHN 750935   64523.67
# 138          138  sORDxbnu  RyEZqUZQ St, AxgHmemodR, AMD 487301   81853.03
# 139          139  qorWZSrc  JSzxdkRz St, mCfUUrzdkM, CHN 217534   96922.23
# 140          140  zFVFgJeP  pQgXBzXH St, McacwZdobd, KOL 424693  128357.48
# 141          141  ofwbHbxR  EmAcRuxN St, sXOthrnQUK, AMD 637608   78804.49
# 142          142  dacBAMpA  YBhLOTSP St, WTTuenTytk, DEL 921107  142806.56
# 143          143  sYYhQnkn  UhgUqwaX St, atiEYYYRyD, BLR 842009  102503.41
# 144          144  eCZFWSZZ  FmTWemsi St, SYNwWdlcMM, MUB 438734  118446.66
# 145          145  ojSVUHdw  UiUJBQKf St, cYZFiICetz, MUB 883607  122362.96
# 146          146  HPuphUPU  exKKqVsz St, VyaNQNeYHU, BLR 911412   78846.32
# 147          147  zGzqAcBm  gJMlKTpu St, EXAZwFRhlY, KOL 153372   81598.01
# 148          148  ogPaHONA  BrLXuusv St, pBZjdIIEam, HYD 450764   63616.99
# 149          149  aCDWqEiV  KJZbuQYr St, tKlAFqiWXF, MUB 274128  136367.22
# 150          150  UsyNMbeP  fOrWMPYX St, znhBtFtgiA, KOL 602646   73404.04
# 151          151  nTFyWCep  vYjIEwAG St, DayaqQqeoz, HYD 200929   95177.50
# 152          152  MlRnjNaA  gGzRXIKk St, tJUUvmywCd, AMD 178854   83539.21
# 153          153  vSgzMDcd  uGXgEHmG St, FvzNqwYbMg, HYD 180758   69869.64
# 154          154  tKPynRSE  reOvLHUb St, vZAHeGAnWB, KOL 571321  103240.99
# 155          155  NQtbjFEe  sKKVFjZs St, SRSItQpqzH, AMD 856445   91362.22
# 156          156  sgBVYNGz  oBlYKpUH St, pfzIojJaWK, AMD 143088  142277.04
# 157          157  GeiRgcXO  YUHkvfDG St, YQkCLIpNUl, BLR 880689   65215.87
# 158          158  optIXlLc  fjezsdBI St, uDNNvSRWyy, PUN 196909  129493.45
# 159          159  UuYloYDm  QuqQsDSP St, koCGCQxkms, BLR 619406   20687.62
# 160          160  UanuHYbn  mHsxlWLA St, KxDcoHOXFv, AMD 279206   54822.96
# 161          161  qaXIfEta  Rrrrjtds St, HDwNrTOtQX, BLR 699706   60492.64
# 162          162  LahjZoqq  MRFEQEGg St, OesBuNEZFS, MUB 643061  109919.98
# 163          163  SGAKSOTY  hsmouNEy St, XVbdgyDlpb, MUB 530401   15364.63
# 164          164  fZkdnlLP  XbdwZWYz St, PQWXpryDvj, AMD 259302   96310.17
# 165          165  wVsuqvPw  OZwIHPEv St, XXsQxqFJUo, MUB 514169  105985.84
# 166          166  CdOqqbeR  nKpzNKjg St, VAlsvowSnh, MUB 148736   82790.95
# 232          232  dKhJcEBA  lKXZCdBS St, KvyaZPCNiL, MUB 637766   83865.83
# 233          233  KBcoXjzC  AZSyZhbO St, FyuJzdTgUy, CHN 248437  125687.81
# 234          234  ARiGSgYK  oKhzIMXv St, oNJdtoQHMN, CHN 645508   81795.16
# 235          235  oVCIeMib  dZgQwZWP St, RRgCBptlGg, CHN 710307   98976.71
# 236          236  rfVVritc  NWMdnynB St, LkSbncitwD, AMD 253882  109170.72
# 237          237  nATpUeod  PVQaRfCw St, lPUThPAItz, BLR 538458  142183.56
# 238          238  ByfxshIg  gZYSCVVK St, tzBOyQyUlU, HYD 599877   63018.39
# 239          239  fABgQRFy  rdVnbomD St, fAUilOrLIb, BLR 176221  123135.57
# 240          240  PagWfdjq  rzpNnYET St, KtNgetypJl, KOL 809387   89675.76
# 241          241  xoBhNyic  dSNspaqG St, QuuNeBGsXh, AMD 573176   93958.04
# 242          242  sAmneMUV  xvBSqQdT St, GptmfhAgmy, DEL 747053  141260.76
# 243          243  criFWtRy  UsrbKeVj St, gqIkKCnDkp, CHN 591226   20847.42
# 244          244  uCdSjALr  KKpFDShd St, YAJExaTasM, HYD 579795   58705.12
# 245          245  wyeKwjwj  mOhbqTSQ St, zvutsUgJUl, AMD 810519  126097.53
# 246          246  pxppUWoR  OpAFghvO St, DaTsaZkDpd, AMD 296844  103112.90
# 247          247  ASwfAMRB  ZyhrEUsL St, UdaCeiEyBS, CHN 126397   64861.82
# 248          248  WXNCExbJ  ThRTvokk St, OFNdCXdcEI, PUN 962647   21456.56
# 249          249  NdvNadpT  KAqvytYG St, WNBIAYunLV, AMD 848914   91687.95
# 250          250  QQCdfhtF  NlfKNRIq St, ikfTPKDwyO, PUN 467617  130340.03
# 251          251  VgMVhOUr  qUXvQrBL St, EGmjazGWzC, AMD 398585  128217.95
# 252          252  OXUFaZvH  FMPXwWkz St, XlQKaomdci, DEL 659655   93963.94
# 253          253  tJnBPJwQ  xWvFJMaQ St, cOWkaHIFuU, AMD 443523  108208.88
# 254          254  pfLnkTNb  cInjsshD St, kMXyNakBxE, DEL 448511  136769.54
# 255          255  KwdhIJTa  OENYwoKo St, RdsNQgmhOX, HYD 324754   98547.93
# 256          256  rgXaRlMu  aDJptZHR St, PVTcAINTDN, HYD 607440  100019.27
# 257          257  SERmuwph  RxqblqLF St, qanrZqoDid, CHN 466385   60481.51
# 258          258  zFEQeyGA  IxbODGlk St, KAmklwAFPv, KOL 485841  128951.25
# 259          259  ggwLaEiw  EhEdBcop St, fUCsSIyKhT, DEL 502779  128650.77
# 260          260  kwZFuorS  AEJozcpn St, aenhYdHcJH, AMD 683264   46697.10
# 261          261  HwhoGDhN  rzQvIeSy St, lLjbqEqSWJ, MUB 289817  138905.60
# 262          262  NawfeJVp  lNmeaYvk St, wzieQDirBT, BLR 719006  120927.08
# 263          263  UgtWlGtl  NGwHbjqw St, SFgCxshUZS, AMD 946421  101031.07
# 264          264  LKYGVcgv  qWLZatOF St, dhkrIuSKjX, BLR 658192  105076.88
# 298          298  oRkoTDOw  dJHUgSxB St, ZVnozJpHXq, CHN 580879   68298.66
# 299          299  lmWLjvpL  XUhIsVci St, whtCXEMoZg, CHN 303608  114764.24
# 300          300  ixGkSZkP  nWJdjxcb St, SqkfRVrxRz, DEL 468747  147091.16
# 301          301  DQShyPwG  UNWTRdaT St, qohLtsrdow, DEL 526893   99457.07
# 302          302  xssjQvCv  hREiMTef St, Cgbnksebvq, KOL 486974   57573.20
# 303          303  nnFLFmAH  EufkecsG St, JcTclfukDC, KOL 858894   79029.57
# 304          304  RhmBRMXM  nEYBWXVm St, XZUbYsXyTi, BLR 344856  104239.00
# 305          305  INLsLrhW  JIQJNybK St, KiIrQlcnmr, MUB 351408  148581.46
# 306          306  lbhRwFIE  vYemcCIX St, wqTOgEAxft, AMD 296060   93375.59
# 307          307  eaKQrblu  xjYaPvqA St, VsMwkqIYcb, MUB 160270  115307.15
# 308          308  zuexviNH  evmEzUJl St, jLRrKNbcvL, MUB 708858  111267.78
# 309          309  kQDkarUv  pwLtUeoJ St, TqruxcXgcl, HYD 368126   79488.49
# 310          310  iQqncawc  IeXdphWU St, RKoXXDSlki, DEL 925007  139170.02
# 311          311  ZrChOIol  XxcLfFDY St, YtNVTrEbLZ, CHN 607385  100837.51
# 312          312  MqZjyIHQ  qhHOVdSA St, GglCGBVFZw, BLR 206040   69963.13
# 313          313  XrRYMXew  JETZNbLs St, DeKSwJGbEU, CHN 680559   83098.09
# 314          314  QTqZjvWv  tJKovFpX St, lvukbHSHAh, PUN 708160   88899.20
# 315          315  dNiKvkEn  hqhAKyWB St, lKIXCuABOK, BLR 640823   55219.00
# 316          316  KSzzriiQ  rbzePVdQ St, cjsirqQtFG, KOL 911374  132384.19
# 317          317  nmoUZqla  PCxkiOav St, arcEYYxBTR, AMD 843868  128442.73
# 318          318  WCPaKEzF  dboqijfF St, ABDeAJhzym, HYD 398204   33498.85
# 319          319  VyVcveSI  QOPiLjoK St, xzlSmqIOUb, CHN 445381   83514.94
# 320          320  aFkkIamj  NKZRwLOn St, ppkAGOCQsk, DEL 245159   75027.43
# 321          321  wZpKmTFV  YulHucRJ St, bMgChXEXZY, KOL 168472  120742.34
# 322          322  eXaPlmNb  JpOqwDSK St, eJKEIjMvqN, CHN 113087   51665.63
# 323          323  TKSZvqtZ  lgkvmGwB St, JkyOwSNLYD, DEL 526290  135537.74
# 324          324  WhMiEUsP  SzsBMqFP St, UQvnvPZsNY, AMD 695730  116425.18
# 325          325  EocVINTh  ppHjmLRh St, ZYBdvgAJVG, KOL 848548  117039.71
# 326          326  RvRFZgqE  vTsepkKl St, WbsSpyhdjK, CHN 522471  115213.16
# 327          327  aiEgqotI  gznnZJYR St, eLsbdBXJLV, KOL 144123  127488.90
# 328          328  VOThUEte  RkrREOkl St, cDendBcXJJ, MUB 723549  125338.36
# 329          329  LqlhxMyD  UOuskjoX St, LffRHfASDb, MUB 962728  134606.52
# 330          330  HbaZeqqb  QHMwgRAr St, IQKMTcBVUg, HYD 578513  130347.13
# 331          331  XbpAzbFI  jwqLdMkV St, FkMQwPDxvI, HYD 790209  110534.05
# 332          332  cWsJBrNl  wfHtSXiu St, maxRiCPGbA, KOL 572071   62498.62
# 333          333  sNCcUdkQ  IUReFhIr St, oufkgAHCKN, AMD 374535  112708.71
# 334          334  MvvsvDkk  njFpIhTo St, NGjYauGUPP, CHN 132177   62431.85
# 335          335  AVKnoJUf  KLNIoFmV St, bvOpHWYqhD, AMD 280706   80680.43
# 336          336  ByKpYYIu  mAiXrFFc St, ZksVHHsvTL, BLR 578547   49416.20
# 337          337  JZoWmTTx  YmXxmauh St, XbVvcOVpNL, BLR 138130   83254.70
# 338          338  qpEUzmfn  PQRNVZuq St, TInRqvlIjZ, KOL 513525   88567.90
# 339          339  CYvKJbyY  lNsZBrWR St, pNpZRVJjjm, CHN 526382  140519.39
# 340          340  hTReZNZH  dnGZvqoc St, hVuooujxEx, CHN 167507   77069.07
# 341          341  ZDcNhCyN  efpTitkr St, idnJhNhhGD, CHN 776471  124550.51
# 342          342  CdtdQzth  qOIciogA St, oaqntskGGg, CHN 337550   61545.52
# 343          343  dnagcWZM  ZwBDIRGB St, UvkahYjZAM, CHN 228900   87455.52
# 344          344  UGjYxkUy  cTvxfzwu St, qqXLBFlawq, HYD 753842   31720.92
# 345          345  AYaprpNK  NrVnkHUc St, bdIVoklboL, PUN 626885  128693.65
# 346          346  hLYcfrev  vVvHFsXj St, OucoCPcRKF, AMD 720102   56012.92
# 347          347  ftIpDBiG  jTompENl St, hPqdqJzBOd, CHN 304295   90532.41
# 348          348  tcGwJhwU  HDpctlbq St, mgucntZfdF, KOL 321474  135022.10
# 349          349  mnFCFYFr  LaFdPHXc St, ehwUqjcNGI, HYD 892717  144952.40
# 350          350  lVwqolYd  ZgIrTJJn St, GHyPNfhBKb, CHN 146366  144756.81
# 351          351  hKXvpsBv  MVgLjZnc St, uUlLBWZPcd, CHN 893842  127395.66
# 352          352  YqGLktyo  wXxEOIVN St, xOdcKuKOAC, PUN 824588   41783.16
# 353          353  vJBjfNiH  pCJLyVtq St, jOgMSEwcEz, AMD 795381  100385.24
# 354          354  oFLoHksU  gwkACrQy St, FJJgAikVsh, DEL 833681  143944.27
# 355          355  ArYlgMBx  kMZZAMJw St, JcgKwKIAPX, DEL 796295  143405.13
# 356          356  nxkBLqXx  WxOCSoYG St, LpMGedcpqH, HYD 132858   29403.81
# 357          357  WOfSjIAu  UNDBHMEt St, YjqkfeeTND, BLR 607144   91155.24
# 358          358  hLttAJZs  RYroAxAM St, cOQuphIpZR, DEL 717258   42031.48
# 359          359  MEImJTyy  uTclhCZi St, dqTvgpesVt, BLR 573395  115745.70
# 360          360  OEQkSsSc  JPEHleix St, vAixoOxkfw, MUB 269564  143308.77
# 361          361  dXvQhEGx  HlwCFiJF St, ZFnVidQJPh, DEL 455870  114677.61
# 362          362  aHUtrBRi  qMzGHubB St, VeQJSJFSDq, PUN 439026   92899.22
# 396          396  KPUWSyxL  EOgMXzzx St, pEkQQDohCP, CHN 475386  102373.31
# 397          397  wLQWjjhS  OCnDeGpN St, hdVZpUSXsx, CHN 424232  125426.72
# 398          398  DuuDywex  nRsJJzeN St, EfSzOenWJj, AMD 413067  141691.22
# 399          399  eumIPZYV  zYnmwPcL St, SdGyzsvqQF, KOL 461351   87045.45
# 400          400  ndKdPWWt  kbRhUtSR St, kYDxHybAwK, PUN 993175   94353.25
# 401          401  UPLXWALa  sDykKczk St, aHYATzEvJc, AMD 873054  113003.82
# 402          402  vOcNSlho  pOtwkpuw St, UxAByWBJzR, KOL 344665  137398.38
# 403          403  PoxpAwkz  ZDFjmlgq St, HfKEMxTbXf, PUN 524129  106371.87
# 404          404  MILazAgm  qTDkuNgB St, TuXfMsaTHc, BLR 307263   80239.41
# 405          405  OMATYAAf  dfBAYRnR St, gkMwPIsvqP, KOL 876034   92330.98
# 406          406  vObLToBk  iaOPOTtK St, QsfkwdXEKG, BLR 496539  145873.06
# 407          407  GFXlTsJx  HwSrgTRh St, ceyrvJwTJf, HYD 899742  132229.07
# 408          408  myXuMIHW  bJvRAFTd St, kPRxAGwdHC, DEL 264104  149983.22
# 409          409  qMHpaHvo  vEiSsVZm St, OPlQeeiMwT, PUN 879630   41453.90
# 410          410  zZzJzzBg  GyENUOWU St, lvAdSRlFbN, KOL 233375  117352.39
# 411          411  FbKMabtZ  kdXSQrzE St, RPegIkrkPe, PUN 662249  149405.66
# 412          412  GQcIUdyW  xenvcTwI St, eCLvHVcezq, BLR 516307   59214.82
# 413          413  OTVjRwqm  WFlLDIpc St, fraobrpMUo, DEL 404306  115516.08
# 414          414  yaTSAiYb  gHoKqpMo St, dUCSzPdxtu, KOL 599225  134321.34
# 415          415  WCdpemzf  pazOKXKu St, nMMVKmxjKe, CHN 251609  105745.65
# 416          416  VrStzZKp  ekNODsSt St, mnIyyFIpuA, PUN 676819   96507.19
# 417          417  urhpeGvR  yMJRHUJP St, KrTDsenjGT, BLR 782647  135023.83
# 418          418  sllKYgWV  liuDgnXj St, OWrhmpGUqI, BLR 382962  113459.19
# 419          419  YmRwjCpB  GDgvItGb St, CBWfGgjsTP, AMD 661738   38563.98
# 420          420  QABCJDOp  IYciLwja St, smhHgThwBF, KOL 269097  119337.44
# 421          421  BFGePuKl  kpJVgkEN St, MzWvkgRGEG, HYD 163060  121365.05
# 422          422  SnGYlnvb  fGruNjhr St, EzBCZdpKOa, CHN 786278   65472.68
# 423          423  noSZwxet  iJKOxxEp St, JnMtJabFyG, PUN 879105  100148.09
# 424          424  cNHZybOj  iBVXytkX St, DErWUccrtt, MUB 849490   41102.50
# 425          425  oeQdoFfS  QbGusOGl St, zubDYVobuF, HYD 295088  107744.64
# 426          426  sEbchmNn  iSqkqUGL St, KRHblEhfyc, PUN 486377   84326.14
# 427          427  PpahZpqe  DuMlTfBY St, BaJxTgSLFj, DEL 491622  104440.91
# 428          428  dpCtinyK  lIzLcmTR St, MxJaDKDupb, BLR 658124  127408.97
# 429          429  ayarDPgk  zfVBSRjo St, RDrgJIKGbh, DEL 400421  136057.67
# 430          430  zkOvyKCp  xiajGNUu St, QUzOrRvQif, MUB 595734  146041.35
# 431          431  YQHOrWwh  OupUDnwZ St, eCqUHAhSGM, CHN 677276   74252.15
# 432          432  SdHAjMuW  eSfCarcZ St, VKlPanLiGz, KOL 224725   78653.05
# 433          433  fIQZTfXf  PdHlDFWH St, mYtGFGVftJ, DEL 964092  100895.19
# 434          434  hkDyUMoN  olrFYDCe St, pIcmDQkSyQ, PUN 507973  129998.86
# 435          435  NunuQLgP  aUxOxqKo St, jAcSzbENmH, BLR 302664  138895.04
# 436          436  MAUUhXDJ  IjPRZBbC St, XBtGBlOlVy, AMD 388450  119504.94
# 437          437  JjbwaMeS  yxFNlvxr St, dzsXLImkGR, BLR 738223   47505.20
# 438          438  AKhbeHta  HPNZYlOF St, veOQRWWEsE, DEL 499785  108480.71
# 439          439  JeTOdAOW  zbptGDJr St, ghzTjtpzHn, MUB 488496  143396.65
# 440          440  CLThoWjz  eHTMlRdC St, SGvxoDtpWh, DEL 732993  127165.42
# 441          441  HHmTZKNr  llCNFrmE St, DMOgfVEWrb, KOL 149640   94380.53
# 442          442  guHwvcxW  BTQloHyf St, lppnsqfxrl, MUB 489048   86547.06
# 443          443  azQxbZxE  PhAslBWh St, TOasrIlktT, PUN 253170   45478.15
# 444          444  HCCkmYtW  fJglKvQM St, jnvAKGtpGh, CHN 911674  102425.72
# 445          445  pIheNjlA  EHRxdbXH St, gyCvgFPnSn, HYD 311955  125324.92
# 446          446  peSIQrai  RJXSLCfM St, DtdRffRZPS, BLR 112301   68260.73
# 447          447  YqZqYLTk  PnnTBDNj St, wclsWADiOX, PUN 668697   50964.49
# 448          448  rqOBPpbU  DroqODLI St, hpnzBjADSG, AMD 429417  137203.89
# 449          449  QUqiaNxd  qwmoMlwf St, ubOFfvsHAq, PUN 793836   99613.94
# 450          450  yuSgPQGj  IQeyJXOL St, APABETpXAH, HYD 331398   18353.89
# 451          451  yIFksFMP  iVFgoHRz St, MZPFCTZMIL, AMD 379796  149387.17
# 452          452  sUYKstLk  otQprJII St, SPaObkmMhw, PUN 513151  112152.94
# 453          453  kViLsofa  bZQHXkqo St, uVCadtDWcm, KOL 417964  146250.15
# 454          454  RcVZmZiE  bYJujznQ St, pLRtxSnukB, CHN 167951  128950.24
# 455          455  luspmOgP  EXCtFYkP St, CEnYplUcEl, HYD 694124   48879.86
# 456          456  apSANibY  pfmGxTjc St, URWTvIQIGE, BLR 969367   75407.34
# 457          457  VVPSmRiQ  UsWKrLXl St, tvJYdTwedB, MUB 415451  149892.98
# 458          458  rGIgCyyc  rOLGzKAh St, nUoYqjOeYh, PUN 533616  105085.71
# 459          459  LBtIXUQW  olqnfGpj St, XjJivLkhWs, BLR 307099   65939.44
# 460          460  jfMjpYjD  iYyroSgF St, cchxWqPgDC, AMD 265842  125284.21
# 461          461  TYOMvBvV  CxCHeZjG St, BoGYJnHufU, AMD 365007  115298.73
# 494          494  XbSWAyZg  HMflpWTT St, KFIJcVlVaT, CHN 942680   49989.08
# 495          495  bVueKYAZ  AZuWQpiX St, NcSoBxrmPI, PUN 876724  149817.64
# 496          496  XbURVWSI  rVKbrtqU St, lPlVGwTUSM, BLR 778563   92404.68
# 497          497  FUoiMwIm  AUbZDTPJ St, LvkAOsJvia, AMD 778581   94618.72
# 498          498  hTRjgpZd  KwVaNfnw St, meUEwACmDe, BLR 113604   44321.05
# 499          499  RNfxWVTa  tDgLGVSu St, vczRVBeLVK, CHN 443262  133556.97
# 500          500  BbBnpjXp  GGWjNKKY St, tkPUNUiKny, KOL 623479   81407.24
# 501          501  amoABVpt  HsNeIFce St, MmyIzRZCWI, DEL 162157  120590.30
# 502          502  PdddWJcL  JFzLpjrN St, VEgtstFkIp, BLR 506620  139743.73
# 503          503  YXuYFuYA  eetsaJWb St, trcugGcznj, CHN 841277   42636.86
# 504          504  wCGReLuJ  JVmNhnJf St, mJDjavvdIA, KOL 172403  141005.52
# 505          505  ShEcQUgG  YzvuVFzJ St, kYcKXYyDVc, DEL 989355  109109.75
# 506          506  QjOVUeDo  EbssCgMl St, dFjMCEPgmW, CHN 767917   43553.18
# 507          507  XTUEjixV  cUnuoiwa St, RXcmwgofcZ, PUN 781152   26475.19
# 508          508  vbBoHMWY  IZZrBgaR St, eobBnZzBda, AMD 785171   71351.62
# 509          509  MQLNMJEz  AmrxozWo St, IEJeqHQJJk, DEL 389180   78127.03
# 510          510  YeyWWaLh  nNrTXVOD St, PlGzNCUqUw, KOL 448447   81900.97
# 511          511  UpYDNmeC  wSwJbuPz St, wzaKbwaMwx, AMD 549424   82813.61
# 512          512  rMwkhThJ  hEfDtsdd St, OuzfdOLCjp, CHN 939062   71894.53
# 513          513  LDGkSPNu  SStsAAAh St, GrCFYsuwOF, KOL 830968  115837.42
# 514          514  ZcyMmEko  TbxCDOJl St, ussXzrhZne, AMD 821549  133101.88
# 515          515  YTYQQDEQ  RhhvOUZB St, DIfvETGbDa, BLR 618022  145287.14
# 516          516  HHSqvGvl  ZkImNnXY St, GIaiWlnBHR, KOL 932176   61517.53
# 517          517  kxrayTgw  XWxgaHHS St, kCNlVXeYWU, PUN 502426  109083.76
# 518          518  pALyUvmV  GTFqOglQ St, pvPtxfbBdF, HYD 578252   96189.78
# 519          519  FVmxLDDn  rNWFTbMr St, rQWwSkTbnP, PUN 578437  112217.39
# 520          520  tcODQnqR  oHUxXJaY St, uDIBTsebfJ, MUB 284883  118202.92
# 521          521  kEUyWDLV  aeBPbIAH St, hAOGHNpPTc, CHN 199504   99674.85
# 522          522  ghSGdoOD  tWghOeDo St, SVoAmGLknu, CHN 818005   62661.50
# 523          523  STTvSAzp  jGFaKqsS St, dQrkUbXOrC, AMD 716684  132705.13
# 524          524  WYqRvYZh  OSCqxlSg St, SzEHiNfnQo, BLR 213297   97352.34
# 525          525  sCMcvVog  YKrVuyFA St, ipcJzfYOUr, CHN 663476   65633.17
# 526          526  RizvRFBF  ixBzPIKg St, WnmpcVKYNJ, HYD 897484   76694.18
# 527          527  VpmFiZyw  LovsgLGr St, qtVEAhkkCY, PUN 356710   91477.11
# 528          528  wwIrqPMg  qbcnmRgA St, uFGzgneaJG, CHN 454004  147390.63
# 529          529  wKqTTwsj  HWPpclgW St, JMIXRbOZpb, KOL 150450  146136.89
# 530          530  oPzrEYWR  HZnSvMtv St, NppMARoKXq, KOL 166281   17318.92
# 531          531  mwLxTDYa  qhwIspfb St, kRflbxtqks, BLR 793961   36699.51
# 532          532  PVTQbbPn  bwZxoWqH St, eWgKVqwvqH, AMD 321631  137437.61
# 533          533  vqqobmGE  felMDoXj St, acsyQAAEPP, CHN 287167   58225.76
# 534          534  MqGTTJls  NWJKCVqz St, TyGOtjANMn, HYD 713590  118662.32
# 535          535  kgFqYsbt  htHjmlGz St, JpLDrAjuSi, HYD 611883   75245.05
# 536          536  IlXXMMXK  ysEjGNae St, jsqLsdYEeF, DEL 869864   85737.32
# 537          537  MAICPYto  kUbcaOfT St, cZjQvAUWeY, KOL 662953  116977.94
# 538          538  Ezzacsmn  jBIJUOwg St, yLaYorfLpW, PUN 686629   93989.39
# 539          539  YkqVxgHi  ZEWSOMtr St, DElIbxVEZA, CHN 379857  119796.03
# 540          540  mECbTLTE  SvITGOSx St, JBUkFvTeln, KOL 567791  141136.74
# 541          541  GlbxvuJB  UuaIZcki St, BWrTubaZtW, KOL 765052  110138.70
# 542          542  GbEMkeOr  ghhjXBRX St, CXLeyVPzeI, PUN 162398  126205.67
# 543          543  NQtBoZoF  pvBtjHIF St, YNwvWxObQE, CHN 853844  118122.37
# 544          544  CGbWEqUn  nfuRBrwY St, LFYsNSAFGD, CHN 357854   79896.94
# 545          545  ESLJKGPE  QUmQvbQx St, CZTMAnAcFn, KOL 813358  105349.37
# 546          546  HtcHRDvw  MqDbEOjB St, PocULBjGsy, PUN 951456  107215.77
# 547          547  sKcXJFop  dFxwdhtY St, fwoauAvaRb, CHN 602553   84545.32
# 548          548  FjScPQYP  qQDIEFFZ St, EpvhRsCZmg, PUN 860038   93042.21
# 549          549  kiTGcEhH  DkseJvjK St, eQmZMhmaiT, CHN 137316   78929.85
# 550          550  VNmgosuh  VEsfNNCk St, ZUEhGmQxXX, DEL 808938  136990.06
# 551          551  gifeXUoY  XIhHswWy St, nYZTHuUkYf, CHN 271761   34851.30
# 552          552  DQctwATO  klYYFNbG St, pUgIoBCGSP, PUN 814374   54901.00
# 553          553  GVZDFYdI  QqIDNDMf St, awxPRWazRT, AMD 191574   95356.76
# 554          554  VmVrCkeT  RTNGReUo St, uqdLxrCgTx, PUN 431974   73993.79
# 555          555  APnFDbOz  HKodTOhw St, GCSxuMbXqG, KOL 303505   93315.94
# 556          556  GmnVOVvt  ixwPfKtD St, AMHXmAAGXO, CHN 135564  144045.82
# 557          557  EFNvnfQt  tNdQHhrX St, avggeGSekT, DEL 733483  149602.08
# 558          558  MBQjdOhO  QeyQjYyt St, tLQSUrGViU, PUN 138844  103638.19
# 559          559  NmJBlysm  eHhftjjK St, nKWdCschPn, AMD 511565   53483.12
# 560          560  MyITtOPS  gvCCIKmC St, KyMozWEvVV, BLR 891078  147494.59
# 561          561  sSGcjgax  ChiFAriF St, AvjWLnegkP, DEL 269732   53044.44
# 562          562  LRmKDfXL  puqcERPR St, stcciUFzse, AMD 599338  101624.42
# 563          563  HzLJnCCw  myRpSXwU St, DaowJsIKMC, MUB 461684  120528.79
# 564          564  hZsYZoGD  yKgkeSuQ St, UOwCFpwuGo, DEL 159930  117028.36
# 565          565  bcPCXZew  zNNOzcVg St, rZVrnEYSWb, PUN 688126   84954.93
# 566          566  aMdFmlqx  EpBRMOLl St, ADFqGkOnDV, DEL 813792   67311.12
# 567          567  owEyfPuW  lnKfbEZf St, bbiyseaUJE, PUN 974611  117457.05
# 568          568  jtxYQyNO  dedlBRWB St, RahVEhGBls, AMD 936843   34008.76
# 569          569  lLvMcRkN  fjmpAqDT St, rbtPJWNdfT, DEL 624130  123305.48
# 570          570  ranpcHiy  foiqbDDR St, kVYJsuIOgc, CHN 815669  147039.97
# 571          571  ASuuSroa  ViAbOzaZ St, mRXRHnqqeA, PUN 740099   79886.43
# 572          572  elnTFdBL  mxOuZVzH St, ytNVjRUMhE, MUB 991597   85847.89
# 573          573  GQjiWfBk  eRbfaqYo St, rhFCNmugVh, MUB 769302  130207.04
# 574          574  CnkiQpFM  GnYWyEZw St, KZbFVLbAIp, PUN 937519  126743.12
# 575          575  YOgaGvUW  RTBvSLPv St, JVEaSHbkHO, BLR 228929  114314.05
# 576          576  MkVfTQOd  zDIloQpZ St, GnGENPAguT, BLR 483553   44785.81
# 577          577  TnJczsDk  aMaJhDPf St, hBezHqucsa, CHN 348827  131917.01
# 578          578  KOtRnuua  ImzgBWAg St, vrJUnTvZSe, DEL 147244   73325.46
# 579          579  lhCMgEKo  cpXsRgxP St, IwlJHkKfct, CHN 140970   53559.19
# 580          580  DJkmOzEJ  TilcAzJv St, kqRcvpmiux, BLR 781165   42379.59
# 581          581  aOWuTmoo  VnCllxgT St, JRzUymLTnm, KOL 189299   98915.68
# 582          582  JHYaSmGO  emQlaTFZ St, naFVJFLUbk, BLR 649619   82142.86
# 583          583  jNLdaRNB  SMKaOqSM St, wqsbNTVnyn, KOL 174121   79505.23
# 584          584  TqPABYbF  YAbXmqOA St, uQeJkdQzYe, BLR 627164  148600.39
# 585          585  nbLcWSfY  IbdeFHLo St, cKOWVtXZhQ, CHN 999439   95282.63
# 586          586  oHrNZnoB  fyToQuwI St, pWknmnCsGg, KOL 182497   88378.37
# 587          587  FmuWNmIO  GXSVDExq St, YjUKwShpxl, AMD 572454   90637.06
# 588          588  kmiUUlnE  cgoazTpl St, fHrZSempXm, DEL 245834   59728.35
# 589          589  CiVZNTTs  hAslgxRq St, twEacZUZnw, MUB 838134   87174.73
# 590          590  PetzdNWi  DwPqsbhS St, rRVeBMwsPw, CHN 417337   19721.91
# 591          591  ySnwzBRf  xPAWECdG St, IQRTDVRGmE, HYD 637994  114216.87
# 4967        1985     Mid Career          1
# 4968        1966  Senior Career          1
# 4969        1973  Senior Career          1
# 4970        1991     Mid Career          1
# 4971        1976  Senior Career          1
# 4972        1992     Mid Career          1
# 4973        2002   Early Career          1
# 4974        1971  Senior Career          1
# 4975        1978  Senior Career          1
# 4976        1984     Mid Career          1
# 4977        1967  Senior Career          1
# 4978        1991     Mid Career          1
# 4979        1992     Mid Career          1
# 4980        1997   Early Career          1
# 4981        2002   Early Career          1
# 4982        1990     Mid Career          1
# 4983        1975  Senior Career          1
# 4984        1986     Mid Career          1
# 4985        1995   Early Career          1
# 4986        1964  Senior Career          1
# 4987        1982     Mid Career          1
# 4988        1969  Senior Career          1
# 4989        1983     Mid Career          1
# 4990        1991     Mid Career          1
# 4991        1976  Senior Career          1
# 4992        1992     Mid Career          1
# 4993        1997   Early Career          1
# 4994        2000   Early Career          1
# 4995        1975  Senior Career          1
# 4996        1972  Senior Career          1
# 4997        1985     Mid Career          1
# 4998        2002   Early Career          1
# 4999        1988     Mid Career          1

# %%
print("Info:")
print(df.info())
# Out:
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          5000 non-null   int64
#  1   Name                5000 non-null   object
#  2   Address             5000 non-null   object
#  3   Salary              5000 non-null   float64
#  4   DOJ                 5000 non-null   object
#  5   DOB                 5000 non-null   object
#  6   Age                 5000 non-null   int64
#  7   Sex                 5000 non-null   object
#  8   Dependents          4877 non-null   float64
#  9   HRA                 5000 non-null   float64
#  10  DA                  5000 non-null   float64
#  11  PF                  5000 non-null   float64
#  12  Gross Salary        5000 non-null   float64
#  13  Insurance           3762 non-null   object
#  14  Marital Status      4877 non-null   object
#  15  In Company Years    5000 non-null   int64
#  16  Year of Experience  5000 non-null   int64
#  17  Department          5000 non-null   object
#  18  Position            5000 non-null   object
# dtypes: float64(6), int64(4), object(9)
# memory usage: 742.3+ KB
# None

# %% [markdown]
# # Step 6: Statistical Summary of Data
#
# We generate descriptive statistics for numerical columns.
# This provides key statistical measures such as mean, minimum, maximum, standard deviation, and quartiles. It helps in understanding the distribution and spread of numerical data.
#
# *Syntax:
# df.describe()*

# %%
print("Statistical Summary of Numerical Data:")
print("-"*35)
df.describe().round(2)
# Out:
# Statistical Summary of Numerical Data:
# -----------------------------------
#        Unnamed: 0     Salary                         DOJ  \
# count     5000.00    5000.00                        5000
# mean      2499.50   93861.63  2014-04-02 21:36:34.560000
# min          0.00   15042.70         1985-02-07 00:00:00
# 25%       1249.75   70556.30         2008-12-08 00:00:00
# 50%       2499.50   96270.79         2016-11-24 00:00:00
# 75%       3749.25  121182.54         2021-06-09 06:00:00
# max       4999.00  149991.34         2024-12-26 00:00:00
# std       1443.52   33931.87                         NaN
#
#                               DOB      Age  Dependents       HRA        DA  \
# count                        5000  5000.00     5000.00   5000.00   5000.00
# mean   1983-09-04 06:36:34.560000    40.38        1.93   7993.40  22152.26
# min           1964-01-02 00:00:00    21.00        0.00   3127.27   3550.22
# 25%           1973-11-13 00:00:00    30.00        1.00   6249.90  16651.97
# 50%           1983-10-23 00:00:00    40.00        2.00   7713.33  22720.84
# 75%           1993-08-11 00:00:00    50.00        3.00   9526.46  28600.26
# max           2002-12-26 00:00:00    60.00        4.00  14787.70  35399.42
# std                           NaN    11.29        1.30   2335.08   8008.25
#
#              PF  Gross Salary  In Company Years  Year of Experience  \
# count   5000.00       5000.00           5000.00             5000.00
# mean   13921.67     110085.62              9.79               19.38
# min     2231.15      22624.83             -1.00                0.00
# 25%    10464.99      85180.22              3.00                9.00
# 50%    14279.00     110617.02              7.00               19.00
# 75%    17973.94     141118.54             15.00               29.00
# max    22246.89     173050.73             39.00               39.00
# std     5032.81      37476.08              8.83               11.29
#
#        Annual_CTC  Joining_Year  Birth_Year  Headcount
# count     5000.00       5000.00     5000.00     5000.0
# mean    154152.94       2013.76     1983.18        1.0
# min      34229.64       1985.00     1964.00        1.0
# 25%     120622.81       2008.00     1973.00        1.0
# 50%     153417.83       2016.00     1983.00        1.0
# 75%     196859.95       2021.00     1993.00        1.0
# max     240603.90       2024.00     2002.00        1.0
# std      51150.80          8.82       11.27        0.0

# %%
print("Statistical Summary of Categorical Data:")
print("-"*35)
df.describe(include=object)
# Out:
# Statistical Summary of Categorical Data:
# -----------------------------------
#             Name                              Address     Sex Insurance  \
# count       5000                                 5000    5000      5000
# unique      5000                                 5000       3         3
# top     VgwbPyBn  jyNxKZtk St, piZQhYcARo, PUN 172813  Female      Both
# freq           1                                    1    1674      2530
#
#        Marital Status       Department Position Dependent_Status  \
# count            5000             5000     5000             5000
# unique              4                5       40                2
# top           Married  Human Resources  QA Lead   Has Dependents
# freq             3052             1035      198             4214
#
#          Career_Stage
# count            5000
# unique              3
# top     Senior Career
# freq             1983

# %% [markdown]
# # CHAPTER 3
# # DATA PRE-PROCESSING
#
# Raw data is rarely perfect for direct analysis. Data pre-processing involves cleaning and transforming the dataset to improve data quality, ensure consistency, and prepare it for accurate analysis and modeling. This step plays a crucial role in eliminating errors, handling missing information, and structuring the data in a meaningful way.
#
# ## 3.1 Handling Missing Values
#
# Missing values can lead to inaccurate results if not handled properly.
# Handling missing values ensures data completeness and prevents errors during analysis.
# First, the check is for the total missing values in each column.
#
#             *Syntax:df.isnull().sum()*
#
# Depending on the requirement, missing values can be:
#
#  a.Filled with appropriate values (mean, median, mode, or a fixed value)
#
#              *Syntax: df.fillna(value, inplace=True)*
#
#  b.Removed if they are very few or irrelevant
#
#              *Syntax: df = df.dropna()*
#
#  In this case we have categorical data as well as numberical data for which the customized syntax is used.
#
#              *Syntax:*
#                   *for col in df.select_dtypes(include=['float64','int64']).columns:
#                     df[col] = df[col].fillna(df[col].mean())*
#
#                  *for col in df.select_dtypes(include=['object']).columns:
#                     df[col] = df[col].fillna(df[col].mode()[0])*

# %%
df.isnull().sum()
# Out:
# Unnamed: 0               0
# Name                     0
# Address                  0
# Salary                   0
# DOJ                      0
# DOB                      0
# Age                      0
# Sex                      0
# Dependents             123
# HRA                      0
# DA                       0
# PF                       0
# Gross Salary             0
# Insurance             1238
# Marital Status         123
# In Company Years         0
# Year of Experience       0
# Department               0
# Position                 0
# dtype: int64

# %%
for col in df.select_dtypes(include=['float64','int64']).columns:
    df[col] = df[col].fillna(df[col].mean())

for col in df.select_dtypes(include=['object']).columns:
    df[col] = df[col].fillna(df[col].mode()[0])

# %% [markdown]
# #### 3.1.1 Verifying if the null values exist or not
#
#                 *Syntax:
#                 df.isnull().sum()*

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# Name                  0
# Address               0
# Salary                0
# DOJ                   0
# DOB                   0
# Age                   0
# Sex                   0
# Dependents            0
# HRA                   0
# DA                    0
# PF                    0
# Gross Salary          0
# Insurance             0
# Marital Status        0
# In Company Years      0
# Year of Experience    0
# Department            0
# Position              0
# dtype: int64

# %% [markdown]
# ## 3.2 Removing Duplicate Records
#
# Duplicate records can distort analysis results by over-representing certain data points. This step ensures that every record in the dataset is unique and contributes fairly to the analysis.
# We check and remove duplicate rows.
#
#                 *Syntax:
#                     original_count = len(df)
#                     df = df.drop_duplicates()
#                     print(f"Removed {original_count - len(df)} duplicate rows.")

# %%
original_count = len(df)
df.drop_duplicates()
print(f"Removed {original_count - len(df)} duplicate rows.")
# Out:
# Removed 0 duplicate rows.

# %% [markdown]
# ## 3.3 Correcting Data Types
#
# Sometimes data is stored in an incorrect format, such as numeric values stored as text or date values stored as strings.
# Correct data types are essential for performing mathematical operations, comparisons, and time-based analysis.
# We convert such columns to the appropriate data types.
#
#             *Syntax:
#                     df["column_name"] = df["column_name"].astype("int")
#                     df["date_column"] = pd.to_datetime(df["date_column"])
#
# Since the datatype of DOJ & DOB was given as object, it is changed to datetime format, and the dependents coloumn is chaged to int which was identified as float in initial checks.

# %%
df['DOJ'] = pd.to_datetime(df['DOJ'], errors='coerce',dayfirst=True)
df['DOB'] = pd.to_datetime(df['DOB'], errors='coerce',dayfirst=True)
if 'Dependents' in df.columns:
    df['Dependents'] = pd.to_numeric(df['Dependents'], errors='coerce').fillna(0).astype(int)

# %% [markdown]
# ##### Verifying the changes

# %%
print("Data types:", df.dtypes)
# Out:
# Data types: Unnamed: 0                     int64
# Name                          object
# Address                       object
# Salary                       float64
# DOJ                   datetime64[ns]
# DOB                   datetime64[ns]
# Age                            int64
# Sex                           object
# Dependents                     int64
# HRA                          float64
# DA                           float64
# PF                           float64
# Gross Salary                 float64
# Insurance                     object
# Marital Status                object
# In Company Years               int64
# Year of Experience             int64
# Department                    object
# Position                      object
# dtype: object

# %% [markdown]
# ## 3.4 Creating Derived Columns
#
# Derived columns are new features created from existing data to provide additional analytical insights. Feature creation enhances the dataset by adding meaningful attributes that support deeper analysis.

# %%
# 1. Annual CTC (Total Cost to Company)
df["Annual_CTC"] = df["Gross Salary"] + df["PF"] + df["HRA"] + df["DA"]

# 2. Experience Band
df["Experience_Band"] = pd.cut(df["Year of Experience"],
                               bins=[0,5,10,20,30,40],
                               labels=["0-5","6-10","11-20","21-30","31+"])

# 3. Age Group
df["Age_Group"] = pd.cut(df["Age"],
                         bins=[18,25,35,45,55,65],
                         labels=["18-25","26-35","36-45","46-55","56+"])

# 4. Service Category
df["Service_Category"] = pd.cut(df["In Company Years"],
                                bins=[0,2,5,10,20,30],
                                labels=["0-2 yrs","3-5 yrs","6-10 yrs","11-20 yrs","21+ yrs"])

# 5. Salary Band
df["Salary_Band"] = pd.cut(df["Salary"],
                           bins=[0,50000,100000,150000,200000],
                           labels=["Low","Medium","High","Very High"])

# 6. Dependent Status
df["Dependent_Status"] = df["Dependents"].apply(lambda x: "Has Dependents" if x > 0 else "No Dependents")

# 7. Joining Year
df["Joining_Year"] = df["DOJ"].dt.year

# 8. Birth Year
df["Birth_Year"] = df["DOB"].dt.year

# 9. Career Stage
df["Career_Stage"] = df["Age"].apply(lambda x:
                                      "Early Career" if x < 30 else
                                      "Mid Career" if x < 45 else
                                      "Senior Career")

# %% [markdown]
# ##### View updated dataset

# %%
df.head()
# Out:
#    Unnamed: 0      Name                              Address     Salary  \
# 0           0  VgwbPyBn  jyNxKZtk St, piZQhYcARo, PUN 172813  149289.04
# 1           1  pgdYaIWk  PypVsqug St, iHyelKZbFc, BLR 580530   69761.64
# 2           2  eWgVBGVv  pfQezTVa St, YfIaELfpUw, BLR 155186  107633.14
# 3           3  LYDofRRu  wcTsbmFr St, UdylzZFFCU, AMD 843852  147408.65
# 4           4  vhLFHcRg  DdxKVhli St, cYOjpbMztB, BLR 713383   53447.06
#
#          DOJ        DOB  Age     Sex  Dependents        HRA  ...  \
# 0 1998-04-27 1971-03-27   53   Other           2   8776.096  ...
# 1 2020-10-24 1997-12-12   26    Male           0   9302.836  ...
# 2 2020-07-22 1979-08-20   44  Female           2  13357.686  ...
# 3 2007-03-27 1966-06-07   58    Male           1   6026.135  ...
# 4 2017-05-23 1992-11-19   31    Male           2   7554.294  ...
#
#                      Position     Annual_CTC  Experience_Band Age_Group  \
# 0              Sales Director  237308.564730              31+     46-55
# 1                HR Executive  121296.163980              0-5     26-35
# 2  Senior Marketing Executive  185153.449090            21-30     36-45
# 3            Account Director  229040.672050              31+       56+
# 4             Sales Executive   93783.700659             6-10     26-35
#
#   Service_Category  Salary_Band  Dependent_Status Joining_Year Birth_Year  \
# 0          21+ yrs         High    Has Dependents         1998       1971
# 1          3-5 yrs       Medium     No Dependents         2020       1997
# 2          3-5 yrs         High    Has Dependents         2020       1979
# 3        11-20 yrs         High    Has Dependents         2007       1966
# 4         6-10 yrs       Medium    Has Dependents         2017       1992
#
#     Career_Stage
# 0  Senior Career
# 1   Early Career
# 2     Mid Career
# 3  Senior Career
# 4     Mid Career
#
# [5 rows x 28 columns]

# %% [markdown]
# ## 3.5 Filtering Data
#
# Filtering allows us to focus on specific subsets of the data based on conditions. This helps in performing targeted analysis for particular categories or groups.
#
#             *Syntax:
#                     filtered_df = df[df["Column_Name"] == "Value"]

# %%
## Employees by Department: Separates employees department-wise for focused departmental analysis.
    
df_sales = df[df["Department"] == "Sales"]
df_hr = df[df["Department"] == "Human Resources"]
df_finance = df[df["Department"] == "Finance"]
df_marketing = df[df["Department"] == "Marketing"]

## Employees by Career Stage: Segments workforce based on career progression levels.
    
df_early_career = df[df["Career_Stage"] == "Early Career"]
df_mid_career = df[df["Career_Stage"] == "Mid Career"]
df_senior_career = df[df["Career_Stage"] == "Senior Career"]

## Employees by Experience Band: Creates experience-based workforce segmentation.

df_exp_0_5 = df[df["Experience_Band"] == "0-5"]
df_exp_6_10 = df[df["Experience_Band"] == "6-10"]
df_exp_11_20 = df[df["Experience_Band"] == "11-20"]
df_exp_21_30 = df[df["Experience_Band"] == "21-30"]
df_exp_31_plus = df[df["Experience_Band"] == "31+"]


## Employees by Salary Band: Identifies compensation-based employee segments.
    
df_low_salary = df[df["Salary_Band"] == "Low"]
df_medium_salary = df[df["Salary_Band"] == "Medium"]
df_high_salary = df[df["Salary_Band"] == "High"]
df_very_high_salary = df[df["Salary_Band"] == "Very High"]

## Employees by Service Category: Segments employees based on tenure in the organization.

df_service_0_2 = df[df["Service_Category"] == "0-2 yrs"]
df_service_3_5 = df[df["Service_Category"] == "3-5 yrs"]
df_service_6_10 = df[df["Service_Category"] == "6-10 yrs"]
df_service_11_20 = df[df["Service_Category"] == "11-20 yrs"]
df_service_21_plus = df[df["Service_Category"] == "21+ yrs"]

## Employees by Dependent Status: Helps analyze benefit-related and demographic workforce trends.

df_with_dependents = df[df["Dependent_Status"] == "Has Dependents"]
df_without_dependents = df[df["Dependent_Status"] == "No Dependents"]

# %% [markdown]
# ##### Verification of the filter

# %%
df_senior_career.head()
# Out:
#    Unnamed: 0      Name                              Address     Salary  \
# 0           0  VgwbPyBn  jyNxKZtk St, piZQhYcARo, PUN 172813  149289.04
# 3           3  LYDofRRu  wcTsbmFr St, UdylzZFFCU, AMD 843852  147408.65
# 6           6  vjbszTQW  LLOOZxHr St, iiZXVGMuRa, DEL 672793  146007.75
# 8           8  sIZQRTaq  ZrqSMeKj St, BSMxlzAcjl, BLR 743922  134973.46
# 9           9  DTjnhgxd  ZEeBgofu St, BGXeaFhWmT, CHN 978281  120881.83
#
#          DOJ        DOB  Age     Sex  Dependents        HRA  ...  \
# 0 1998-04-27 1971-03-27   53   Other           2   8776.096  ...
# 3 2007-03-27 1966-06-07   58    Male           1   6026.135  ...
# 6 2022-07-12 1971-12-04   52   Other           2   6581.225  ...
# 8 2005-11-06 1965-11-05   58   Other           1   9632.654  ...
# 9 2006-12-23 1968-09-24   55  Female           2  10167.817  ...
#
#                      Position    Annual_CTC  Experience_Band Age_Group  \
# 0              Sales Director  237308.56473              31+     46-55
# 3            Account Director  229040.67205              31+       56+
# 6       National Account Head  228088.70000              31+     46-55
# 8              Technical Lead  217948.86829              31+       56+
# 9  National Marketing Manager  198276.04065              31+     46-55
#
#   Service_Category  Salary_Band  Dependent_Status Joining_Year Birth_Year  \
# 0          21+ yrs         High    Has Dependents         1998       1971
# 3        11-20 yrs         High    Has Dependents         2007       1966
# 6          0-2 yrs         High    Has Dependents         2022       1971
# 8        11-20 yrs         High    Has Dependents         2005       1965
# 9        11-20 yrs         High    Has Dependents         2006       1968
#
#     Career_Stage
# 0  Senior Career
# 3  Senior Career
# 6  Senior Career
# 8  Senior Career
# 9  Senior Career
#
# [5 rows x 28 columns]

# %% [markdown]
# ## 3.6 Aggregating Data
#
# Aggregation is used to summarize data and extract higher-level insights.This helps in understanding trends, averages, and comparisons across different groups.
#
#             *Syntax:
#                     aggregated_df = df.groupby("Group_Column")["Target_Column"].agg("mean")

# %%
# Department-wise Headcount
df["Headcount"] = 1
dept_headcount = df.groupby("Department")["Headcount"].sum()

# Department-wise Average Annual CTC
dept_avg_ctc = df.groupby("Department")["Annual_CTC"].mean().round(2)

# Experience Band-wise Headcount
exp_band_headcount = df.groupby("Experience_Band",observed=True)["Headcount"].sum()

# Age Group-wise Headcount
age_group_distribution = df.groupby("Age_Group",observed=True)["Headcount"].sum()

# Service Category-wise Headcount
service_category_distribution = df.groupby("Service_Category",observed=True)["Headcount"].sum()

# Gender Distribution
gender_distribution = df.groupby("Sex")["Headcount"].sum()

# Marital Status Distribution
marital_status_distribution = df.groupby("Marital Status")["Headcount"].sum()

# Department-wise Average Salary
dept_avg_salary = df.groupby("Department")["Salary"].mean().round(2)

# Career Stage-wise Average Annual CTC
career_stage_ctc = df.groupby("Career_Stage")["Annual_CTC"].mean().round(2)

# Experience Band-wise Average Salary
exp_band_salary = df.groupby("Experience_Band",observed=True)["Salary"].mean().round(2)

# Dependent Status-wise Average Annual CTC
dependent_ctc = df.groupby("Dependent_Status")["Annual_CTC"].mean().round(2)

# Joining Year-wise Headcount Trend
joining_trend = df.groupby("Joining_Year")["Headcount"].sum()

# Birth Year-wise Workforce Distribution
birth_year_distribution = df.groupby("Birth_Year")["Headcount"].sum()

# %% [markdown]
# ##### Verify the agregation

# %%
dept_headcount.reset_index()
# Out:
#         Department  Headcount
# 0          Finance        989
# 1  Human Resources       1035
# 2               IT       1005
# 3        Marketing        967
# 4            Sales       1004

# %% [markdown]
# # CHAPTER 4
# # EXPLORATORY DATA ANALYSIS(EDA)
#
# Exploratory Data Analysis (EDA) is conducted to uncover trends, relationships, and patterns in employee experience, departmental distribution, and salary structure. This helps understand how experience influences compensation and how salary patterns differ across departments. The exploratory data analysis focuses on:
#
#         - Understanding the distribution of key variables such as Year of Experience and Salary.
#         - Examining the relationship between Experience and Salary.
#         - Analyzing department-wise compensation patterns.
#         - Evaluating combined effects of Department and Experience on Salary.
#         - Measuring correlation between numerical attributes.
# This step provides data-driven evidence to support conclusions on experience–salary alignment and departmental pay variations.
#
# ## 4.1 Univariate Analysis
#
# Univariate analysis examines individual variables independently to understand their distribution.
#
#                 -Year of Experience distribution shows workforce experience spread.
#                 -Salary distribution shows compensation range.
#                 -Experience_Band simplifies experience grouping.
#                 -Salary_Band simplifies salary grouping.
# This helps identify workforce composition and salary structure before studying relationships.

# %%
# Summary statistics of Experience and Salary
df["Year of Experience"].describe()
# Out:
# count    5000.000000
# mean       19.378600
# std        11.293023
# min         0.000000
# 25%         9.000000
# 50%        19.000000
# 75%        29.000000
# max        39.000000
# Name: Year of Experience, dtype: float64

# %%
df["Salary"].describe()
# Out:
# count      5000.000000
# mean      93861.627080
# std       33931.869545
# min       15042.700000
# 25%       70556.305000
# 50%       96270.790000
# 75%      121182.540000
# max      149991.340000
# Name: Salary, dtype: float64

# %%
# Experience Band distribution
df["Experience_Band"].value_counts()
# Out:
# Experience_Band
# 11-20    1268
# 21-30    1265
# 31+      1087
# 6-10      661
# 0-5       652
# Name: count, dtype: int64

# %%
# Salary Band distribution
df["Salary_Band"].value_counts()
# Out:
# Salary_Band
# High         2294
# Medium       2077
# Low           629
# Very High       0
# Name: count, dtype: int64

# %% [markdown]
# ## 4.2 Bivariate Analysis
#
# Bivariate analysis explores relationships between two variables.
#
# - Experience vs Salary shows whether compensation increases with experience.
# - Department vs Salary shows compensation differences across departments.
# - The salary spread across various department helps in easy department wise comparison.
#
# This helps in understanding experience-driven pay and departmental salary variation.

# %%
# Average Salary by Experience Band
df.groupby("Experience_Band", observed=False)["Salary"].mean().round(2)
# Out:
# Experience_Band
# 0-5       41142.04
# 6-10      60199.50
# 11-20     92746.03
# 21-30    112117.04
# 31+      129895.20
# Name: Salary, dtype: float64

# %%
# Average Salary by Department
df.groupby("Department")["Salary"].mean().round(2)
# Out:
# Department
# Finance            93993.74
# Human Resources    92111.46
# IT                 92918.62
# Marketing          93307.02
# Sales              97013.81
# Name: Salary, dtype: float64

# %%
# Salary Spread across departments
pd.pivot_table(
    df,
    values="Salary",
    index="Department",
    aggfunc=["min", "max", "mean", "median", "std"]
).round(2)
# Out:
#                       min        max      mean    median       std
#                    Salary     Salary    Salary    Salary    Salary
# Department
# Finance          15099.73  149983.22  93993.74  97038.75  34147.93
# Human Resources  15878.60  149991.34  92111.46  94393.73  34152.55
# IT               15300.39  149899.80  92918.62  94266.84  34062.26
# Marketing        15332.27  149838.75  93307.02  96333.25  33699.97
# Sales            15042.70  149591.15  97013.81  99765.04  33435.06

# %% [markdown]
# ## 4.3 Multivariate Analysis
#
# Multivariate analysis examines the combined influence of multiple factors on salary.
#
# - Department and Experience_Band are analyzed together against Salary.
# - This identifies whether employees with similar experience receive different pay across departments.
#
# This directly supports the objective of exploring departmental compensation patterns.

# %%
# Department vs Experience Band Salary matrix
pd.pivot_table(df,
               values="Salary",
               index="Department",
               columns="Experience_Band",
               aggfunc="mean",
                observed = False)
# Out:
# Experience_Band           0-5          6-10         11-20          21-30  \
# Department
# Finance          40340.909672  60112.623162  92418.274082  112662.146324
# Human Resources  42618.529542  60791.771216  92573.610314  112824.157361
# IT               40008.769712  59915.693852  92639.454723  110638.613373
# Marketing        41841.813759  60597.967846  92556.525806  113623.970084
# Sales            40535.298571  59455.339520  93549.846225  110864.184960
#
# Experience_Band            31+
# Department
# Finance          128395.197919
# Human Resources  130321.377641
# IT               130466.642788
# Marketing        129607.622228
# Sales            130614.093372

# %% [markdown]
# The pivot table displays how salary varies across departments and experience levels together.
# It highlights combined influence of role function and experience on compensation.

# %% [markdown]
# ## 4.4 Correlation Analysis
#
# Correlation measures the strength and direction of relationships between numerical variables.

# %%
df[["Year of Experience", "Salary"]].corr()
# Out:
#                     Year of Experience    Salary
# Year of Experience            1.000000  0.897075
# Salary                        0.897075  1.000000

# %% [markdown]
# ### Correlation Between Department and Salary
#
# Correlation analysis can only be performed between numeric variables.
# In this dataset, the Department column is a categorical (text) variable containing values such as Sales, Finance, Marketing, HR, etc. Since correlation requires numeric inputs, attempting to compute **correlation between Department and Salary will result in error.**
#
# To analyze how salary varies across departments, we use **groupby and pivot table analysis** instead of correlation.
# This approach helps compare **average, median, and spread of salaries** across different departments, which directly supports the project objective of identifying **departmental variations in pay structure**.

# %% [markdown]
# # CHAPTER 5
# # VISUALIZATIONS
#
# This chapter presents visual representations of findings from the Exploratory Data Analysis.
# The charts help in understanding employee experience distribution, salary structure, departmental compensation differences, and the relationship between experience and salary.
#
# Matlab and Seaborn are imported as the primary step for creating visualisation

# %%
#Importing matlab and seaborn
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 5.1 Year of Experience Distribution (Histogram)
# This histogram provides a detailed view of the workforce composition by illustrating how employees are distributed across different years of experience, helping to understand the overall experience spread within the organization.

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["Year of Experience"], bins=15, kde=True)
plt.title("Distribution of Year of Experience")
plt.xlabel("Years of Experience")
plt.ylabel("Employee Count")
plt.show()

# %% [markdown]
# # 5.2 Salary Distribution (Histogram)
# This histogram visualizes the range and frequency of employee salaries, allowing us to identify common compensation levels, potential outliers, and the overall salary structure in the organization.

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["Salary"], bins=20, kde=True)
plt.title("Distribution of Salary")
plt.xlabel("Salary")
plt.ylabel("Employee Count")
plt.show()

# %% [markdown]
# # 5.3 Experience Band Composition (Bar Chart)
# This bar chart displays the number of employees in each predefined experience band, providing insight into workforce segmentation and making it easier to analyze patterns of compensation across different experience groups.

# %%
plt.figure(figsize=(7,5))
sns.countplot(x="Experience_Band", data=df)
plt.title("Employees by Experience Band")
plt.xlabel("Experience Band")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # 5. 4 Salary Band Composition (Bar Chart)
# This bar chart represents the distribution of employees across salary bands, offering a clear view of how compensation is spread across the organization and highlighting areas with higher or lower salary concentrations.

# %%
plt.figure(figsize=(7,5))
sns.countplot(x="Salary_Band", data=df)
plt.title("Employees by Salary Band")
plt.xlabel("Salary Band")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # 5.5 Average Salary by Department (Bar Plot)
# This bar plot compares the mean salaries across all departments, helping to identify departmental variations in compensation and assess whether pay structures are consistent with organizational objectives.

# %%
dept_salary = df.groupby("Department")["Salary"].mean().round(2)

plt.figure(figsize=(8,5))
sns.barplot(x=dept_salary.index, y=dept_salary.values)
plt.title("Average Salary by Department")
plt.xlabel("Department")
plt.ylabel("Average Salary")
plt.show()

# %% [markdown]
# # 5.6 Salary Spread Across Departments (Box Plot)
# This box plot illustrates the variability and distribution of salaries within each department, allowing identification of differences in pay dispersion, presence of outliers, and insights into salary fairness across departments.

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x="Department", y="Salary", data=df)
plt.title("Salary Spread by Department")
plt.xlabel("Department")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# # 5.7 Experience vs Salary Relationship (Scatter Plot)
# This scatter plot shows the relationship between years of experience and salary for individual employees, enabling us to visually assess whether compensation generally increases with experience and to spot any deviations.

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x="Year of Experience", y="Salary", data=df)
plt.title("Experience vs Salary")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# # 5.8 Average Salary by Experience Band (Line Chart)
# This line chart presents the trend of average salaries across different experience bands, making it easier to observe how compensation progresses as employees gain experience and whether growth is consistent across the organization.

# %%
exp_salary = df.groupby(("Experience_Band"),observed=True)["Salary"].mean().round(2)

plt.figure(figsize=(8,5))
plt.plot(exp_salary.index, exp_salary.values, marker="o")
plt.title("Average Salary by Experience Band")
plt.xlabel("Experience Band")
plt.ylabel("Average Salary")
plt.show()

# %% [markdown]
# # 5.9 Department vs Experience Band Salary Heatmap (Multivariate)
# This heatmap displays the average salary across departments and experience bands in a single matrix, providing a comprehensive view of how experience and departmental affiliation together influence compensation patterns.

# %%
salary_pivot = pd.pivot_table(df,
                               values="Salary",
                               index="Department",
                               columns="Experience_Band",
                               aggfunc="mean",
                               observed=False)

plt.figure(figsize=(10,6))
sns.heatmap(salary_pivot, annot=True, fmt=".0f", cmap="YlGnBu")
plt.title("Average Salary by Department and Experience Band")
plt.xlabel("Experience Band")
plt.ylabel("Department")
plt.show()

# %% [markdown]
# # 5.10 Correlation Heatmap
# This correlation heatmap quantifies the strength and direction of the relationship between years of experience and salary, giving statistical support to the hypothesis that experience significantly influences compensation.

# %%
corr_matrix = df[["Year of Experience", "Salary"]].corr()

plt.figure(figsize=(6,4))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# ## 5.11 Comparative Visualization of Salary Distribution Across Departments and Experience Levels
# The first plot compares average salaries across departments for clear departmental pay comparison, while the second plot shows how salary increases with years of experience.

# %%
fig, axes = plt.subplots(1, 2, figsize=(14,5))

# Plot 1: Department vs Salary (Box Plot)
sns.boxplot(x="Department", y="Salary", data=df, ax=axes[0])
axes[0].set_title("Salary Distribution Across Departments")
axes[0].set_xlabel("Department")
axes[0].set_ylabel("Salary")

# Plot 2: Experience vs Salary (Scatter Plot)
sns.scatterplot(x="Year of Experience", y="Salary", data=df, ax=axes[1])
axes[1].set_title("Experience vs Salary")
axes[1].set_xlabel("Years of Experience")
axes[1].set_ylabel("Salary")

plt.tight_layout()
plt.show()

# %% [markdown]
# # CHAPTER 6
# # INSIGHT GENERATION, STRATEGIC ACTIONS & BUSINESS RECOMMENDATIONS
#
# ## 6.1 Overall Findings Summary
#
# This exploratory data analysis examines employee experience, departmental distribution, and salary structure to understand how experience influences compensation and whether salary progression is consistently aligned across departments. The analysis reveals a strong positive relationship between experience and salary, along with notable but controlled departmental variations in compensation.
#
# Overall, the findings indicate that experience is the primary driver of salary growth across the organization, while departments follow broadly similar pay progression patterns with minor deviations at higher experience levels.
#
# ## 🎯 Core Discoveries
#
# **Primary Finding:**
#
# Employee salary increases consistently with experience across all departments, supported by a strong correlation (≈ 0.90) between Years of Experience and Salary. While departments differ in functional roles, compensation structures remain largely aligned, suggesting standardized pay bands with limited departmental bias.
#
# **Key Analytical Evidence:**
#
#     -Experience–Salary correlation coefficient: ~0.897, indicating a strong positive relationship
#
#     -Salary increases steadily across Experience_Bands (0–5, 6–10, 11–20, 21–30, 31+)
#
#     -Department-wise salary differences are more visible at senior experience levels than at entry levels
#
# ## 6.2 Key Insights Derived from the Analysis
#
# ### Insight 1: Experience–Salary Alignment
#
# **Finding:**
# A strong positive correlation is observed between years of experience and salary, indicating that salary increases consistently with experience.
#
# **Interpretation:**
# Compensation decisions in the organization are primarily experience-driven, suggesting that tenure and accumulated expertise form the foundation of pay determination.
#
# **Strategic Action:**
# Define structured experience-based salary progression rules with fixed salary ranges for each experience band.
#
# **Business Recommendation:**
# Use experience bands as the primary compensation anchor while periodically validating salary ranges using internal historical data to ensure consistency across departments.
#
# ### Insight 2: Higher Salary Growth at Senior Experience Levels
#
# **Finding:**
# Salary increments between higher experience bands are significantly larger compared to early experience bands.
#
# **Interpretation:**
# The organization places greater monetary value on advanced experience, leadership capability, and long-term organizational contribution.
#
# **Strategic Action:**
# Introduce differentiated salary growth mechanisms for senior experience bands to formally recognize higher contribution levels.
#
# **Business Recommendation:**
# Allocate a higher portion of compensation budgets to senior experience bands to retain critical expertise and reduce leadership attrition risks.
#
# ### Insight 3: Well-Defined Salary Bands Across Experience Levels
#
# **Finding:**
# Salary distributions across experience bands show minimal overlap, indicating clearly defined compensation slabs.
#
# **Interpretation:**
# This reflects a structured and disciplined salary architecture that supports internal equity and reduces ambiguity in pay progression.
#
# **Strategic Action:**
# Maintain and periodically review salary band definitions to ensure continued relevance as workforce composition evolves.
#
# **Business Recommendation:**
# Institutionalize salary band audits using internal salary distribution analysis to prevent compression and maintain equitable pay progression.
#
# ### Insight 4: Departmental Salary Variations Within Experience Bands
#
# **Finding:**
# Employees with the same experience level receive different average salaries across departments.
#
# **Interpretation:**
# Departmental functions introduce role-specific pay variations, reflecting differences in skill demand and functional complexity.
#
# **Strategic Action:**
# Define department-specific compensation adjustment factors layered on top of experience-based salary bands.
#
# **Business Recommendation:**
# Justify departmental salary differences through documented role complexity and skill requirements rather than ad-hoc pay decisions.
#
# ### Insight 5: Combined Influence of Experience and Department on Salary
#
# **Finding:**
# Multivariate analysis shows that both department and experience together influence salary outcomes.
#
# **Interpretation:**
# Compensation decisions are multi-dimensional, balancing experience progression with functional role valuation.
#
# **Strategic Action:**
# Adopt a hybrid compensation framework integrating experience bands with department-based role valuation.
#
# **Business Recommendation:**
# Use combined experience–department salary matrices as decision-support tools during compensation planning cycles.
#
# ### Insight 6: Consistent Salary Progression Trends Across Departments
#
# **Finding:**
# Salary progression patterns across experience bands remain consistent across departments.
#
# **Interpretation:**
# This consistency indicates strong centralized compensation governance and policy enforcement.
#
# **Strategic Action:**
# Continue centralized oversight of salary progression policies across departments.
#
# **Business Recommendation:**
# Monitor department-level deviations through periodic salary trend reviews to ensure sustained policy adherence.
#
# ### Insight 7: Workforce Concentration in Early and Mid Experience Bands
#
# **Finding:**
# Most employees fall within early to mid experience levels, with fewer employees in senior bands.
#
# **Interpretation:**
# The organization exhibits a typical workforce pyramid structure, emphasizing the importance of internal talent progression.
#
# **Strategic Action:**
# Strengthen structured career progression pathways to move employees from mid to senior experience bands.
#
# **Business Recommendation:**
# Align learning and development investments with experience band transitions to support long-term workforce sustainability.
#
# ## 6.3 Conclusion
#
# This study demonstrates that employee compensation is strongly aligned with experience, supported by structured salary bands and consistent progression patterns. Departmental variations in salary exist but are systematically layered on top of experience-based frameworks, indicating disciplined compensation governance. By formalizing experience-driven salary structures, validating departmental pay differences, and strengthening progression pathways, the organization can enhance pay equity, retention, and long-term workforce stability.
